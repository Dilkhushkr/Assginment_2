# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel('flight_price.xlsx')

# %%
# Q1. Load the flight price dataset and examine its dimensions. How many rows and columns does the
# dataset have?
i,j=df.shape

# %%
print("The number of rows:",i)
print("The number of columns ",j)
# Out:
# The number of rows: 10683
# The number of columns  11

# %%
df.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %%
# Q2. What is the distribution of flight prices in the dataset? Create a histogram to visualize the
# distribution.
## To visualize the distribution of the data in your DataFrame is called Distribution
plt.figure(figsize=(10,6))
# for col in df.columns:
plt.hist(df['Airline'],bins = 10,alpha=0.5, label=col)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Data Distribution')
plt.legend()
plt.grid(True)
plt.show()

# %%
#Q3. What is the range of prices in the dataset? What is the minimum and maximum price?
print("The maximum value of the price data set is :",df['Price'].max())
print("The minimum value of the price data set is :",df['Price'].min())
print("And range of this data is :",df['Price'].max()-df['Price'].min())
# Out:
# The maximum value of the price data set is : 79512
# The minimum value of the price data set is : 1759
# And range of this data is : 77753

# %%
# Q4. How does the price of flights vary by airline? Create a boxplot to compare the prices of different
# airlines.
df.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x = 'Airline', y = 'Price',data = df)
plt.title('Price of Flights by Airline')
plt.xlabel('Airline')
plt.ylabel('Price')
plt.show()

# %%
# Q5. Are there any outliers in the dataset? Identify any potential outliers using a boxplot and describe how
# they may impact your analysis.

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x = df['Price'])
plt.title('Boxplot of Flight Prices')
plt.xlabel('Price')
# Out:
# Text(0.5, 0, 'Price')

# %%
## Yes there are many more outlier here but i do not think it will impact while analsis

# %%
# Q6. You are working for a travel agency, and your boss has asked you to analyze the Flight Price dataset
# to identify the peak travel season. What features would you analyze to identify the peak season, and how
# would you present your findings to your boss?

# %%
#Ans:-
# To identify the peak travel season from the Flight Price dataset, several features can be analyzed. Here's a structured approach:

# Features to Analyze:
# Date or Time Information: Analyze flight prices over different months, weeks, or days of the week to identify patterns.
# Historical Data: Compare current flight prices with historical data from previous years to identify recurring patterns in peak seasons.
# Destination and Origin: Identify specific destinations or origins that experience increased demand during certain times of the year.
# Special Events or Holidays: Consider the impact of holidays, festivals, or special events at specific destinations that might drive up travel demand and prices.
# Steps to Present Findings:
# Data Visualization: Utilize line plots, bar charts, or heatmaps to visualize the trends in flight prices over time, highlighting periods of peak demand.
# Statistical Analysis: Calculate average prices, price variations, and price distributions for different time periods and destinations to quantify peak seasons.
# Identify Trends: Identify consistent patterns or trends in flight prices over time, such as price spikes during specific months or around holidays.
# Comparative Analysis: Compare flight prices across different destinations and time periods to identify regions or seasons with the highest demand and prices.
# Recommendations: Based on the analysis, provide recommendations to your boss regarding the peak travel season, including specific time periods, popular destinations, and expected price fluctuations.
# Forecasting: Use predictive modeling or time series analysis to forecast future trends in flight prices and anticipate upcoming peak seasons.
# Presentation Format:
# Executive Summary: Provide a concise overview of the findings, highlighting the identified peak travel seasons and key insights.
# Visualizations: Present visually appealing charts and graphs to illustrate the trends in flight prices over time and across different destinations.
# Key Findings: Summarize the key findings, including the identified peak seasons, factors influencing price fluctuations, and notable trends observed in the data.
# Recommendations: Offer actionable recommendations based on the analysis, such as marketing strategies, pricing strategies, or targeted promotions to capitalize on peak travel seasons.
# Future Considerations: Discuss potential future considerations, such as ongoing monitoring of flight prices, adapting strategies based on changing market conditions, and incorporating feedback from customers and stakeholders.

# %%
# Q7. You are a data analyst for a flight booking website, and you have been asked to analyze the Flight
# Price dataset to identify any trends in flight prices. What features would you analyze to identify these
# trends, and what visualizations would you use to present your findings to your team?

# %%
# Features to Analyze:
# Date or Time Information: Analyze flight prices over different time periods (months, weeks, days) to identify seasonal trends.
# Flight Routes: Analyze prices for different flight routes to identify routes with the highest and lowest price fluctuations.
# Airline Comparison: Compare flight prices across different airlines to identify trends and differences in pricing strategies.
# Booking Window: Analyze how far in advance flights are booked and its impact on prices.
# Special Events or Holidays: Identify any significant price fluctuations around holidays, festivals, or special events.
# Visualizations to Use:
# Time Series Plots: Use line plots to visualize how flight prices change over time, with time on the x-axis and price on the y-axis. This can help identify seasonal trends and patterns.
# Boxplots: Utilize boxplots to compare the distribution of flight prices across different airlines, routes, or time periods. This can help identify outliers and variations in pricing.
# Heatmaps: Use heatmaps to visualize flight prices across different dates and destinations, with colors representing price levels. This can help identify peak travel seasons and popular destinations.
# Scatterplots: Create scatterplots to visualize the relationship between booking window and flight prices. This can help identify any correlation between booking timing and price fluctuations.
# Bar Charts: Use bar charts to compare average flight prices across different airlines, routes, or time periods. This can help highlight trends and differences in pricing strategies.
# Regression Analysis: Perform regression analysis to identify any significant factors influencing flight prices, such as time of booking, airline, route, or special events.
# Presentation of Findings:
# Executive Summary: Provide a brief overview of the key findings, highlighting any significant trends or insights discovered during the analysis.
# Visualizations: Present a variety of visualizations, including time series plots, boxplots, heatmaps, scatterplots, and bar charts, to effectively communicate trends in flight prices.
# Key Findings: Summarize the key findings from the analysis, including any seasonal trends, differences in pricing across airlines or routes, and the impact of booking timing on flight prices.
# Recommendations: Offer recommendations to the team based on the analysis, such as adjusting pricing strategies, targeting promotions during peak travel seasons, or optimizing booking windows to maximize revenue.
# Future Analysis: Discuss potential areas for further analysis, such as exploring the impact of external factors (e.g., economic conditions, fuel prices) on flight prices or conducting predictive modeling to forecast future price trends.

# %%
# Q8. You are a data scientist working for an airline company, and you have been asked to analyze the
# Flight Price dataset to identify the factors that affect flight prices. What features would you analyze to
# identify these factors, and how would you present your findings to the management team?

# %%
# Ans:-Date and Time Information: Analyze flight prices over different time periods (months, weeks, days) to identify seasonal trends and fluctuations.

# Flight Routes: Analyze prices for different flight routes to identify routes with higher or lower prices.
# Airline: Analyze prices across different airlines to identify variations in pricing strategies.
# Booking Window: Analyze how far in advance flights are booked and its impact on prices.
# Day of the Week: Analyze prices based on the day of the week to identify any pricing patterns related to weekdays or weekends.
# Special Events or Holidays: Identify any significant price fluctuations around holidays, festivals, or special events.
# Flight Duration: Analyze the relationship between flight duration and prices to identify any correlation.
# Presentation of Findings:
# Executive Summary: Provide a concise summary of the key findings, highlighting the factors that most significantly impact flight prices.
# Visualizations: Use a variety of visualizations such as line plots, bar charts, scatter plots, and heatmaps to effectively communicate the relationships between different features and flight prices.
# Key Findings: Summarize the main findings from the analysis, including any significant factors that influence flight prices and the magnitude of their impact.
# Regression Analysis: Present the results of regression analysis to quantify the relationship between flight prices and various factors, providing insights into the direction and strength of these relationships.
# Recommendations: Offer actionable recommendations to the management team based on the analysis, such as adjusting pricing strategies, optimizing booking windows, or targeting promotions during peak travel seasons.
# Future Considerations: Discuss potential areas for further analysis or data collection, such as exploring the impact of external factors (e.g., economic conditions, fuel prices) on flight prices or conducting predictive modeling to forecast future price trends.
# Ineractive Dashboards: Consider creating interactive dashboards that allow the management team to explore the data and visualize the relationships between different factors and flight prices in real-time.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv')

# %%
# Q9. Load the Google Playstore dataset and examine its dimensions. How many rows and columns does
# the dataset have?
x,y=df.shape
print("Counts of the rows :",x)
print("Counts of the columns :",y)
# Out:
# Counts of the rows : 10841
# Counts of the columns : 13

# %%
# Q10. How does the rating of apps vary by category? Create a boxplot to compare the ratings of different
# app categories.

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x = 'Category', y = 'Rating',data = df)
plt.title("Rating of App by Category")
plt.xlabel('Category')
plt.ylabel('Rating')
# Out:
# Text(0, 0.5, 'Rating')

# %%
# Q11. Are there any missing values in the dataset? Identify any missing values and describe how they may
# impact your analysis.

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
## In Rating columns there are many more missing values which is not good analysis because the concept comes to data losing

# %%
# Q12. What is the relationship between the size of an app and its rating? Create a scatter plot to visualize
# the relationship.

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
plt.figure(figsize=(60,20))
plt.scatter(df['Size'],df['Rating'],color = 'blue',alpha = 0.5)
plt.title('Relationship between App Size and Rating')
plt.xlabel("Size")
plt.ylabel("Rating")
# Out:
# Text(0, 0.5, 'Rating')

# %%
#Q13. How does the type of app affect its price? Create a bar chart to compare average prices by app type.

# %%
# Ans :-This is do difficulte for me i could not understand it
# df.columns

# %%
# df['Type'].unique()[0:2]

# %%
# Q14. What are the top 10 most popular apps in the dataset? Create a frequency table to identify the apps
# with the highest number of installs.

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df['Installs'] = df['Installs'].str.replace('+', '',regex=True)
df['Installs'] = df['Installs'].str.replace(',', '',regex=True)
df['Installs'] = df['Installs'].replace('Free', '0')

# %%
df['Installs'] = pd.to_numeric(df['Installs'])

# %%
install_freq = df.groupby('App')['Installs'].sum().reset_index()

# %%
top_10_apps = install_freq.nlargest(10,'Installs')
print('This is in top 10:')
top_10_apps
# Out:
# This is in top 10:
#                                App    Installs
# 8080                Subway Surfers  6000000000
# 4924                  Google Drive  4000000000
# 4933                   Google News  4000000000
# 4937                 Google Photos  4000000000
# 5118                      Hangouts  4000000000
# 5399                     Instagram  4000000000
# 2364              Candy Crush Saga  3500000000
# 4869                         Gmail  3000000000
# 4921  Google Chrome: Fast & Secure  3000000000
# 6051     Maps - Navigate & Explore  3000000000

# %%
# Q15. A company wants to launch a new app on the Google Playstore and has asked you to analyze the
# Google Playstore dataset to identify the most popular app categories. How would you approach this
# task, and what features would you analyze to make recommendations to the company?

# %%
# Data Exploration: Explore the Google Play Store dataset to understand its structure and the available features.

# Identify Relevant Features: Identify features in the dataset that can help determine app popularity. Some relevant features may include:
# App Category: The category or genre of the app.
# Installs: The number of times the app has been installed.
# Ratings: The average user ratings of the app.
# Reviews: The number of user reviews for the app.
# Size: The size of the app.
# Price: The price of the app (if applicable).
# Last Updated: The date when the app was last updated.
# Analysis and Visualization: Analyze the dataset to determine which categories have the highest number of installs, ratings, or reviews. Visualize these metrics using bar charts, pie charts, or other relevant visualizations to compare the popularity of different app categories.
# Statistical Analysis: Perform statistical analysis to identify correlations between app category and popularity metrics (installs, ratings, reviews). This can help determine if certain categories tend to have higher popularity metrics than others.
# User Preferences: Consider factors such as user demographics and preferences when analyzing app popularity. For example, certain categories may be more popular among specific age groups or geographic regions.
# Trends and Patterns: Identify any trends or patterns in app popularity over time. For example, certain categories may experience seasonal variations in popularity.
# Recommendations: Based on the analysis, make recommendations to the company regarding the most popular app categories on the Google Play Store. Consider factors such as market demand, competition, and potential profitability when making recommendations.
# Further Analysis: Consider conducting further analysis, such as sentiment analysis of user reviews or clustering analysis to identify subcategories within popular app categories.

# %%
# Q16. A mobile app development company wants to analyze the Google Playstore dataset to identify the
# most successful app developers. What features would you analyze to make recommendations to the
# company, and what data visualizations would you use to present your findings?

# %%
# Features to Analyze:
# Number of Installs: Analyze the total number of installs for apps developed by each developer.

# Ratings and Reviews: Consider the average ratings and the total number of reviews received by apps from each developer.
# App Portfolio: Look at the size and diversity of the app portfolio for each developer. A developer with a larger and more diverse portfolio may indicate success.
# App Size and Updates: Analyze the size of the apps and the frequency of updates. Successful developers may have apps that are regularly updated and optimized.
# Revenue: If available, analyze revenue data such as in-app purchases, subscriptions, or ad revenue generated by apps from each developer.
# User Engagement: Consider metrics such as daily active users (DAU), monthly active users (MAU), and user retention rates for apps developed by each developer.
# Data Visualizations:
# Bar Charts: Use bar charts to compare the total number of installs, average ratings, and total reviews for apps from each developer.
# Pie Charts: Visualize the distribution of app categories within the portfolio of each developer using pie charts.
# Scatter Plots: Create scatter plots to explore the relationship between app size, number of updates, and user ratings for apps developed by each developer.
# Heatmaps: Use heatmaps to visualize the distribution of app ratings and reviews across different categories for each developer.
# Stacked Bar Charts: Compare the revenue generated by apps from each developer using stacked bar charts, showing the contribution from different revenue sources (e.g., in-app purchases, ads).
# Time Series Plots: Analyze the trend of app updates over time for each developer using time series plots.
# Boxplots: Compare the distribution of app sizes for apps developed by each developer using boxplots.

# %%
Q17. A marketing research firm wants to analyze the Google Playstore dataset to identify the best time to
launch a new app. What features would you analyze to make recommendations to the company, and
what data visualizations would you use to present your findings?
